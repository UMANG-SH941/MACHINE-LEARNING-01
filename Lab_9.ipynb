# %% [markdown]
# <a href="https://colab.research.google.com/github/UMANG-SH941/ALGO-LEARNING-01/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %%
import heapq

def dijkstra(graph, source):
    # Initialize distances with infinity
    distances = {node: float('inf') for node in graph}
    distances[source] = 0

    # Priority queue for selecting the node with smallest distance
    pq = [(0, source)]

    # Dictionary to store shortest paths
    paths = {node: [] for node in graph}
    paths[source] = [source]

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        # Skip if we already found a shorter path
        if current_distance > distances[current_node]:
            continue

        # Explore neighbors
        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight

            # If a shorter path is found
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(pq, (distance, neighbor))
                paths[neighbor] = paths[current_node] + [neighbor]

    return distances, paths

# %%
#user input graph
graph = {
    'A': {'B': 2, 'C': 4},
    'B': {'A': 2, 'C': 1, 'D': 7},
    'C': {'A': 4, 'B': 1, 'E': 3},
    'D': {'B': 7, 'E': 2, 'F': 5},
    'E': {'C': 3, 'D': 2, 'F': 1},
    'F': {'D': 5, 'E': 1}
}

# --- Step 2: Display shortest paths ---
def display_results(source):
    distances, paths = dijkstra(graph, source)
    print(f"\nShortest paths from {source}:")
    for node in graph:
        print(f"To {node}: Path = {paths[node]}, Distance = {distances[node]}")

# --- Step 3: Add two more nodes ---
graph['G'] = {'E': 2, 'F': 3}
graph['H'] = {'F': 4, 'G': 1}

# --- Step 4: Test with different sources ---
display_results('A')
display_results('C')
display_results('G')
# Out:
# Shortest paths from A:
# To A: Path = ['A'], Distance = 0
# To B: Path = ['A', 'B'], Distance = 2
# To C: Path = ['A', 'B', 'C'], Distance = 3
# To D: Path = ['A', 'B', 'C', 'E', 'D'], Distance = 8
# To E: Path = ['A', 'B', 'C', 'E'], Distance = 6
# To F: Path = ['A', 'B', 'C', 'E', 'F'], Distance = 7
# To G: Path = [], Distance = inf
# To H: Path = [], Distance = inf
#
# Shortest paths from C:
# To A: Path = ['C', 'B', 'A'], Distance = 3
# To B: Path = ['C', 'B'], Distance = 1
# To C: Path = ['C'], Distance = 0
# To D: Path = ['C', 'E', 'D'], Distance = 5
# To E: Path = ['C', 'E'], Distance = 3
# To F: Path = ['C', 'E', 'F'], Distance = 4
# To G: Path = [], Distance = inf
# To H: Path = [], Distance = inf
#
# Shortest paths from G:
# To A: Path = ['G', 'E', 'C', 'B', 'A'], Distance = 8
# To B: Path = ['G', 'E', 'C', 'B'], Distance = 6
# To C: Path = ['G', 'E', 'C'], Distance = 5
# To D: Path = ['G', 'E', 'D'], Distance = 4
# To E: Path = ['G', 'E'], Distance = 2
# To F: Path = ['G', 'F'], Distance = 3
# To G: Path = ['G'], Distance = 0
# To H: Path = [], Distance = inf

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
